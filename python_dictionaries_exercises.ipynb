# %% [markdown]
# <a href="https://colab.research.google.com/github/ximeee-oss/Tareas-/blob/main/python_dictionaries_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Dictionary Exercises

# %%
# 1
student = {'name': 'Ximena', 'age': 16, 'grade': '11'}
print(student)
# Out:
# {'name': 'Ximena', 'age': 16, 'grade': '11'}

# %%
# 2
car = {'brand': 'Toyota', 'model': 'Corolla', 'year': 2020}
print(car['brand'])
# Out:
# Toyota

# %%
# 3
car = {'brand': 'Toyota', 'model': 'Corolla', 'year': 2020}
print(car['year'])
# Out:
# 2020

# %%
# 4
person = {'name': 'Alice', 'age': 25}
person['city'] = 'Bogota'
print(person)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Bogota'}

# %%
# 5
person = {'name': 'Alice', 'age': 25, 'city': 'Bogota'}
person['age'] = 26
print(person)
# Out:
# {'name': 'Alice', 'age': 26, 'city': 'Bogota'}

# %%
# 6
person = {'name': 'Alice', 'age': 25, 'city': 'Bogota'}
person.pop('city')
print(person)
# Out:
# {'name': 'Alice', 'age': 25}

# %%
# 7
fruits = {'apple': 3, 'banana': 5, 'orange': 2}
print(fruits.keys())
# Out:
# dict_keys(['apple', 'banana', 'orange'])

# %%
# 8
fruits = {'apple': 3, 'banana': 5, 'orange': 2}
print(fruits.values())
# Out:
# dict_values([3, 5, 2])

# %%
# 9
fruits = {'apple': 3, 'banana': 5, 'orange': 2}
for k, v in fruits.items():
    print(k, v)
# Out:
# apple 3
# banana 5
# orange 2

# %%
# 10
grades = {'Ana': 85, 'Luis': 90, 'Maria': 78}
print('Luis' in grades)
# Out:
# True

# %%
# 11
grades = {'Ana': 85, 'Luis': 90, 'Maria': 78}
print('Pedro' in grades)
# Out:
# False

# %%
# 12
numbers = {'a': 10, 'b': 20, 'c': 30}
print(sum(numbers.values()))
# Out:
# 60

# %%
# 13
inventory = {'pens': 10, 'notebooks': 5, 'erasers': 8}
print(len(inventory))
# Out:
# 3

# %%
# 14
countries = {'Colombia': 'Bogota', 'France': 'Paris', 'Japan': 'Tokyo'}
for country, capital in countries.items():
    print(country, '-', capital)
# Out:
# Colombia - Bogota
# France - Paris
# Japan - Tokyo

# %%
# 15
temperatures = {'Monday': 22, 'Tuesday': 24, 'Wednesday': 21, 'Thursday': 23}
print(max(temperatures.values()))
# Out:
# 24
